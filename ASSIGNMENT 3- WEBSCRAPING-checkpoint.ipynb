# %% [markdown]
# # Hello , I completed Q4,5,6,7,8,9 and got good results , but Q1,2,3,10 tried to solve in many ways and couldnot solve.
#    kindly accpet this work.

# %%
# Let's first install python library
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common import keys
from selenium.webdriver.common.by import By
import time

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %% [markdown]
# # Q1. Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
url = "https://www.naukri.com"
driver.get(url)

# finding element for job search bar
search_job = driver.find_elements(By.XPATH, 'qsb-search-sugg')
search_job

# write on search bar
search_job.send_key('Data Analyst')


# finding element for job location bar
search_loc=driver.find_elements(By.XPATH, 'qsb-location-sugg')
search_loc.send_key("Bangalore")

search_btn= driver.find_element(By.XPATH, "//button[@class='btn']")
search_btn

# clicking  using xpath function
search_btn=driver.find_element(By.XPATH, "//button[@class='btn']")
search_btn.click()

#so let's extract all the tags having the job titles
title_tags=driver.find_elements(By.XPATH, "//a[@class='title fw500 ellipsis']")
title_tags

# extract the text of the job title  from the tags
job_titles=[]
for i in title_tags:
    if i.text is None:
        job_titles.append('Not')
    else:
        job_titles.append(i.text)
job_titles[:10]  

# lets extract all the tags having company names
company_tags=driver.find_elements(By.XPATH, "//a[@class='subTitle ellipsis fleft']")
company_tags

# Now we will extract the text from the tags by looping over these tags
companies_names=[]

for i in company_tags:
    companies_names.append(i.text)
companies_names[:10]    

# so lets extract  all the tags having the experience required data
experience_tags=driver.find_elements(By.XPATH, "//li[@class='fleft grey-text br2 placeHolderLi experience'] //span")
experience_tags

# no we will extract the text  from these tags only by one by looping over these tags
experience_list=[]
for i in experience_tags:
    experience_list.append(i.text)
experience_list[:10]   

locations_tags=driver.find_elements(By.XPATH,  "//li[@class='fleft grey-text br2 placeHolderLi location']/span")
locations_tags

locations_list=[]
for i in locations_tags:
    locations_list.append(i.text)
locations_list[:10]    

#So lets check th length of ech element.
print(len(job_titles[:10])),print(len(companies_names[:10])),print(len(experience_list[:10])),print(len(locations_list[:10]))

jobs=pd.DataFrame({})
jobs['title']=job_titles[:10]
jobs['company']=companies_names[:10]
jobs['experience_required']=experience_list[:10]
jobs['location']=locations_list[:10]
                                                                                                                       
jobs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19200/1638638878.py in <module>
#       8
#       9 # write on search bar
# ---> 10 search_job.send_key('Data Analyst')
#      11
#      12
#
# AttributeError: 'list' object has no attribute 'send_key'

# %%
# I tried many ways to findout the error shown- but i couldnot make possible

# %% [markdown]
# # Q2.Scraping job-title, job-location, company_name by serching for data - “Data Scientist” Job position in “Bangalore” location

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url = "https://www.naukri.com."
driver.get(url)
time.sleep(5)


# finding element for job search bar

search_job = driver.find_elements(By.XPATH, "//input[@class='sugInp']")  
search_job.send_keys('Data Scientist')

# finding element for job location bar
search_loc = driver.find_element(By.XPATH, 'qsb-location-sugg')  
search_loc.send_keys("Bangalore")

# clicking  using xpath function
search_btn = driver.find_element(By.XPATH, "//button[@class='btn']")  
search_btn.click()
time.sleep(5)
#so let's extract all the tags having the job titles

title_tags = driver.find_elements(By.XPATH , "//a[@class='title fw500 ellipsis']")


# extract the text of the job title  from the tags
job_titles=[]
for i in title_tags:
    if i.text is None:
        job_titles.append('Not')
    else:
        job_titles.append(i.text)
   

# lets extract all the tags having company names
company_tags = driver.find_elements(By.XPATH , "//a[@class='subTitle ellipsis fleft']")

# Now we will extract the text from the tags by looping over these tags
companies_names=[]

for i in company_tags:
    companies_names.append(i.text)


# so lets extract  all the tags having the job location

location_tags = driver.find_elements(By.XPATH ,"//li[@class='fleft grey-text br2 placeHolderLi location']/span")

# now we will extract the text  from these tags only by one by looping over these tags
location_list=[]
for i in location_tags:
    location_list.append(i.text)


#extracting when the job posting was posted
posted_tags = driver.find_elements(By.XPATH ,'//time[@ class="sx2jih0 zcydq84u"]/span')
posted_list=[]
for i in posted_tags:
    posted_list.append(i.text)

jobs=pd.DataFrame({})
jobs['title']=job_titles[:10]
jobs['company']=companies_names[:10]
jobs['location']=location_list[:10]
#jobs['Posted']=posted_list[:10]

driver.close()

jobs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19200/2426499965.py in <module>
#       9
#      10 search_job = driver.find_elements(By.XPATH, "//input[@class='sugInp']")
# ---> 11 search_job.send_keys('Data Scientist')
#      12
#      13 # finding element for job location bar
#
# AttributeError: 'list' object has no attribute 'send_keys'

# %%
# I tried many ways to findout the error shown- but i couldnot make possible

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
#
# You have to use the location and salary filter.
#
# You have to scrape data for “Data Scientist” designation for first 10 job results.
#
# You have to scrape the job-title, job-location, company_name, experience_required.
#
# The location filter to be used is “Delhi/NCR”
#
# The salary filter to be used is “3-6” lakhs

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url = "https://www.naukri.com"
driver.get(url)
time.sleep(5)

# %%
# finding element for job search bar
search_job = driver.find_elements(By.XPATH, "//input[@class='sugInp']")
search_job

# write on search bar
search_job.send_key['Data Scientist']


# finding element for job location bar
search_loc = driver.find_elements(By.XPATH, 'qsb-location-sugg')  
search_loc.send_keys("Bangalore")

# clicking  using xpath function
search_btn = driver.find_element(By.XPATH, "//button[@class='btn']")  
search_btn.click()
time.sleep(5)
#so let's extract all the tags having the job titles


filter_loc = driver.find_element(By.XPATH, '//span[@title="Delhi / NCR"]')
filter_loc.click()

filter_salary = driver.find_element(By.XPATH, '//label[@for="chk-3-6 Lakhs-ctcFilter-"]/p/span[1]')
filter_salary.click()



title_t1=driver.find_elements(BY.XPATH,  "//a[@class='title fw500 ellipsis']")
title_t1

# extract the text of the job title  from the tags
job_titles=[]
for i in title_tags:
    if i.text is None:
        job_titles.append('Not')
    else:
        job_titles.append(i.text)
   

# lets extract all the tags having company names
company_tags = driver.find_elements(By.XPATH,   '//a[@class="subTitle ellipsis fleft"]')

# Now we will extract the text from the tags by looping over these tags
companies_names=[]

for i in company_tags:
    companies_names.append(i.text)


# so lets extract  all the tags having the job location

location_tags = driver.find_elements(By.XPATH ,'//li[@class="fleft grey-text br2 placeHolderLi location"]')

# now we will extract the text  from these tags only by one by looping over these tags
location_list=[]
for i in location_tags:
    location_list.append(i.text)


#extracting when the job posting was posted
exp_tags = driver.find_elements(By.XPATH ,'//li[@class="fleft grey-text br2 placeHolderLi experience"]/i')

exp_list=[]
for i in exp_tags:
    exp_list.append(i.text)

jobs=pd.DataFrame({})
jobs['title']=job_titles[:10]
jobs['company']=companies_names[:10]
jobs['location']=location_list[:10]
jobs['Experience needed']=exp_list[:10]

driver.close()

jobs
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19200/1306416706.py in <module>
#       1 # finding element for job search bar
# ----> 2 search_job = driver.find_elements(By.XPATH, "//input[@class='sugInp']")
#       3 search_job
#       4
#       5 # write on search bar
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#     886         # Return empty list if driver returns null
#     887         # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 888         return self.execute(Command.FIND_ELEMENTS, {
#     889             'using': by,
#     890             'value': value})['value'] or []
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
# I tried many ways to findout the error shown- but i couldnot make possible

# %% [markdown]
# # Q4 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#
# Brand
#
# Product Description
#
# Price
#
# Discount %
#
# The attributes which you have to scrape is ticked marked in the below image.

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(10)

esc_login = driver.find_element(By.XPATH , '//button[@class="_2KpZ6l _2doB4z"]')
esc_login.click()

search_product = driver.find_element(By.XPATH, '//input[@class="_3704LK"]')  
search_product.send_keys('Sunglasses')

search_btn = driver.find_element(By.XPATH, '//button[@class="L0Z3Pu"]')  
search_btn.click()
time.sleep(5)

B_name=[]
Price=[]
P_desc=[]
Discount=[]

for i in range(3):
    b_name=driver.find_elements(By.XPATH, "//div[@class='_2WkVRV']")
    p_desc=driver.find_elements(By.XPATH, "//a[@class='IRpwTa']")
    price =driver.find_elements(By.XPATH, "//div[@class='_25b18c']")
    discount=driver.find_elements(By.XPATH, "//div[@class='_3Ay6Sb']")
    
    for j  in b_name:
        B_name.append(j.text)
    B_name[:100]    
    
    
    
    for k in p_desc:
        P_desc.append(k.text)
    P_desc[:100] 
    
    
    for l in price:
        Price.append(l.text)
    Price[:100] 
    
    
    for t in discount:
        Discount.append(t.text)
    Discount[:100]
    
sun_gl=pd.DataFrame({})
sun_gl['Brand_name']=B_name[:100]
sun_gl['Price']=Price[:100]
sun_gl['Description']=P_desc[:100]
sun_gl['Discount']=Discount[:100]

driver.close()

sun_gl
# Out:
#            Brand_name                Price  \
# 0            Fastrack      ₹799₹99920% off
# 1           Elligator    ₹298₹2,49588% off
# 2                SRPM    ₹200₹1,29984% off
# 3              SUNBEE    ₹283₹1,29978% off
# 4           New Specs    ₹265₹1,99986% off
# ..                ...                  ...
# 95  SHAAH COLLECTIONS    ₹252₹2,59990% off
# 96             PIRASO      ₹639₹79920% off
# 97           Fastrack    ₹279₹1,59982% off
# 98            Dannilo    ₹359₹2,59986% off
# 99           Fastrack  ₹1,169₹1,29910% off
#
#                                           Description Discount
# 0       UV Protection Wayfarer Sunglasses (Free Size)  20% off
# 1                 UV Protection Round Sunglasses (54)  88% off
# 2              UV Protection Wayfarer Sunglasses (50)  84% off
# 3   UV Protection, Polarized Wayfarer Sunglasses (...  78% off
# 4    UV Protection Rectangular Sunglasses (Free Size)  86% off
# ..                                                ...      ...
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.
# This task will be done in following steps:
# 1. First get the webpage https://www.flipkart.com/
# 2. Enter “iphone 11” in “Search” field .
# 3. Then click the search button.

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(10)

esc_login = driver.find_element(By.XPATH , '//button[@class="_2KpZ6l _2doB4z"]')
esc_login.click()

search_product = driver.find_element(By.XPATH, '//input[@class="_3704LK"]')  
search_product.send_keys('iphone 11')

search_btn = driver.find_element(By.XPATH, '//button[@class="L0Z3Pu"]')  
search_btn.click()
time.sleep(5)

product = driver.find_element(By.XPATH, '//div[@class="col col-7-12"]')
product.click()
time.sleep(5)

p = driver.current_window_handle
parent = driver.window_handles[0]
child = driver.window_handles[1]

driver.switch_to.window(child)


show_all_reviews = driver.find_element(By.XPATH, '//div[@class="_3UAT2v _16PBlm"]/span')
show_all_reviews.click()
time.sleep(5)

Rating=[]
Review_summary=[]
Full_Review=[]


for i in range(10):
     
    
    rating_tags = driver.find_elements(By.XPATH, '//div[@class="_3LWZlK _1BLPMq"]')
    review_summary_tags = driver.find_elements(By.XPATH, '//p[@class="_2-N8zT"]')
    full_review_tags = driver.find_elements(By.XPATH, '//div[@class="t-ZTKy"]/div/div')


    for rating in rating_tags:
        Rating.append(rating.text)
        
    for review in review_summary_tags:
        Review_summary.append(review.text)
    
    for review in full_review_tags:
        Full_Review.append(review.text)
    
    time.sleep(5)
    
    next_button = driver.find_element(By.XPATH, '//a[@class="_1LKTO3"]')
    next_button.click()
    
    time.sleep(5)
    
reviews = pd.DataFrame({})
reviews['Rating']=Rating
reviews['Review_summary'] = Review_summary
reviews['Full_Review'] = Full_Review

driver.close()

reviews
# Out:
#    Rating       Review_summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       5   Highly recommended
# 4       5    Worth every penny
# ..    ...                  ...
# 95      5     Perfect product!
# 96      5             Terrific
# 97      5            Wonderful
# 98      5    Worth every penny
# 99      5       Simply awesome
#
#                                           Full_Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   What a camera .....just awesome ..you can feel...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  Iphone is just awesome.. battery backup is ver...
# 96  Really worth of money. i just love it. It is t...
# 97  This is my first ever I phone. Before this I w...
# ...

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com
# search for “sneakers” in the search field.
#
# You have to scrape 4 attributes of each sneaker :
#
# 1.Brand
#
# 2.Product Description
#
# 3.Price
#
# 4.discount %

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url="https://www.flipkart.com/"
driver.get(url)
time.sleep(5)

esc_login = driver.find_element(By.XPATH , '//button[@class="_2KpZ6l _2doB4z"]')
esc_login.click()

# finding element for job search bar
search_g= driver.find_element(By.XPATH,"//input[@type='text']")

# write on search bar
search_g.send_keys('sneakers')

search_btn=driver.find_element(By.XPATH,"//button[@class='L0Z3Pu']")

search_btn=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search_btn.click()
time.sleep(5)

B_name=[]
Price=[]
P_desc=[]
Discount=[]


for i in range(3):
    b_name=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    p_desc=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    price =driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    discount=driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']")
    
    for j  in b_name:
        B_name.append(j.text)
    B_name[:100]    
    
    
    
    for k in p_desc:
        P_desc.append(k.text)
    P_desc[:100] 
    
    
    for l in price:
        Price.append(l.text)
    Price[:100] 
    
    
    for t in discount:
        Discount.append(t.text)
    Discount[:100]
    
sun_gl=pd.DataFrame({})
sun_gl['Brand_name']=B_name[:100]
sun_gl['price']=Price[:100]
sun_gl['Product description']=P_desc[:100]
sun_gl['discount']=Discount[:100]

driver.close()


sun_gl
# Out:
#      Brand_name   price                                Product description  \
# 0        BRUTON    ₹399      Modern Trendy Sneakers Shoes Sneakers For Men
# 1        BRUTON    ₹599  Combo Pack Of 4 Casual Shoes Loafer Shoes Snea...
# 2      Magnolia    ₹374                                   Sneakers For Men
# 3          PUMA  ₹3,134                       Rebound JOY Sneakers For Men
# 4          PUMA  ₹2,946                             Glory Sneakers For Men
# ..          ...     ...                                                ...
# 95     RapidBox    ₹570                    Serve Pro Lite Sneakers For Men
# 96       Layasa    ₹399             Puma Smash Wns v2 L Sneakers For Women
# 97     URBANBOX    ₹197                                 Sneakers For Women
# 98    Deals4you    ₹349                          Sneakers Sneakers For Men
# 99  Feet Runner    ₹349                                   Sneakers For Men
#
#    discount
# 0   69% off
# 1   82% off
# 2   62% off
# 3   43% off
# ...

# %% [markdown]
# # Q7: Go to the link - https://www.myntra.com/shoes
# Set second Price filter and Color filter to “Black”, as shown in the below image.

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url="https://www.myntra.com/shoes"
driver.get(url)
time.sleep(10)

#Applying the black colur filter
filter_button2 = driver.find_element(By.XPATH,'//li[@class="colour-listItem"][1]')
filter_button2.click()
time.sleep(5)  

# appplying the price filter
filter_button1=driver.find_element(By.XPATH,'//ul[@class="price-list"]/li[2]/label')
filter_button1.click()
time.sleep(5)


Brand=[]
Price=[]
Description=[]

for i in range(2):
    brand=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    description=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    price =driver.find_elements(By.XPATH,'//div[@class="product-price"]')
 
    for j  in brand:
        Brand.append(j.text)
    
    for k in description:
        Description.append(k.text)
    
    for l in price:
        temp = l.text.split('Rs.' , 2)
        if len(temp) == 3:
            l = temp[1]
        else: l = temp[1]
        Price.append(l)


myntra_shoes = pd.DataFrame()
myntra_shoes["Brand"] = Brand
myntra_shoes['Description'] = Description
myntra_shoes['Price in INR'] = Price

driver.close()

myntra_shoes
# Out:
#                    Brand                     Description Price in INR
# 0                   Nike  Men ZOOM WINFLO8 Running Shoes         7880
# 1                   Nike      Men Colourblocked Sneakers        10795
# 2                   Nike           Air Max Axis Sneakers         8355
# 3       ADIDAS Originals        Men Niteball II Sneakers        10449
# 4               Skechers      Men Max Cushioning Running         8099
# ..                   ...                             ...          ...
# 95                  Nike  Men Zoom C Pro HC Tennis Shoes         7560
# 96                  Puma           Women Enlighten Shoes         6999
# 97        Tommy Hilfiger              Men Solid Sneakers         7999
# 98  FORCLAZ By Decathlon                Men Hiking Shoes         6999
# 99      ADIDAS Originals       Men Woven NMD_31 Sneakers        12599
#
# [100 rows x 3 columns]

# %%
myntra_shoes[:20]
# Out:
#                Brand                        Description Price in INR
# 0               Nike     Men ZOOM WINFLO8 Running Shoes         7880
# 1               Nike         Men Colourblocked Sneakers        10795
# 2               Nike              Air Max Axis Sneakers         8355
# 3   ADIDAS Originals           Men Niteball II Sneakers        10449
# 4           Skechers         Men Max Cushioning Running         8099
# 5             ADIDAS          Women X9000 H.RDY Running         6719
# 6               Nike     Men JORDAN LOW Basketball Shoe        12795
# 7     Tommy Hilfiger                 Men Solid Sneakers         8099
# 8       UNDER ARMOUR         Men Charged Breeze Running         8099
# 9       Hush Puppies  Men Solid Leather Formal Slip-Ons         7649
# 10      UNDER ARMOUR      Unisex Curry Basketball Shoes        10999
# 11              Puma      Women UltraRide Running Shoes         8999
# 12              Puma         Unisex Wild Rider Sneakers         7649
# ...

# %% [markdown]
# # Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image:
#    After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

url=" https://www.amazon.in "
driver.get(url)
time.sleep(10)

search_g = driver.find_element(By.XPATH,"//input[@type='text']")
search_g.send_keys('Laptop')

search_btn=driver.find_element(By.XPATH,"//input[@id='nav-search-submit-button']")
search_btn.click()
time.sleep(5)

intelcorei7 = driver.find_element(By.XPATH, '//li[@aria-label="Intel Core i7"]')
intelcorei7.click()
time.sleep(5)

Title=[]
Price=[]
Rating=[]


title=(driver.find_elements(By.XPATH, '//span[@class="a-size-medium a-color-base a-text-normal"]'))[:10]
ratings=(driver.find_elements(By.XPATH,' //span[@class="a-size-base s-underline-text"]'))[:10]
price =(driver.find_elements(By.XPATH, '//span[@aria-hidden="true"]/span[2]'))[:10]


for j  in title:
    Title.append(j.text)




for k in ratings:
    Rating.append(k.text)



for l in price:
    Price.append(l.text)
    
laptops = pd.DataFrame()

laptops["Title"] = Title
laptops["Price"] = Price
laptops["Rating"] = Rating

driver.close()

laptops
# Out:
#                                                Title     Price Rating
# 0  HP 15s- 11th Gen Intel Core i5 -8GB RAM/512GB ...  Featured     62
# 1  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...    53,900    691
# 2  Lenovo IdeaPad Slim 3 Intel Celeron N4020 15.6...    39,990     57
# 3  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...    29,980  1,597
# 4  Lenovo IdeaPad Slim 1 Intel Celeron N4020 11.6...    25,990    585
# 5  HP Chromebook x360 Intel Celeron N4120 14 inch...    21,789    691
# 6  HP 14s, 5th Gen AMD Ryzen 3- 8GB RAM/512GB SSD...    39,990    200
# 7  ASUS VivoBook 14 (2021), 14-inch (35.56 cm) HD...    29,490    360
# 8  HP 15s, 11th Gen Intel Core i3, 8GB RAM/512GB ...    59,490
# 9  ASUS VivoBook 14 (2021), 14-inch (35.56 cm) HD...

# %% [markdown]
# # Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida
# location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.
# This task will be done in following steps:

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))


url= "https://www.ambitionbox.com/"
driver.get(url)
time.sleep(10)

jobs = driver.find_element(By.XPATH,'//a[@title="Jobs"]')
jobs.click()
time.sleep(5)

search = driver.find_element(By.NAME,'ab_jobsSearch')
search.send_keys('Data Scientist')

search_btn = driver.find_element(By.XPATH,'//div[@class="fixed-typeahead-wrapper"]/div/div/button')
search_btn.click()
time.sleep(5)

location = driver.find_element(By.XPATH, '//div[@title="Location"]')
location.click()

noida = driver.find_element(By.XPATH, '//label[@for="location_Noida"]')
noida.click()
time.sleep(5)

company_name_tags = driver.find_elements(By.XPATH, '//a[@class="title noclick"]')
ratings_tags = driver.find_elements(By.XPATH, '//span[@class="body-small"]')
posted_tags = driver.find_elements(By.XPATH, '//div[@class="other-info"]/span[1]')


Company_name = []
Rating = []
Posted_on = []

for tag in company_name_tags:
    Company_name.append(tag.text)
    
for tag in ratings_tags:
    Rating.append(tag.text)
    
for tag in posted_tags:
    Posted_on.append(tag.text)
    

jobs = pd.DataFrame()

jobs["Company_name"] = Company_name
jobs["Rating"] = Rating
jobs["Posted_on"] = Posted_on

driver.close()

jobs
# Out:
#                                         Company_name Rating Posted_on
# 0    Hiring Data Scientist #productbasecompany #CBRE    4.3   10d ago
# 1  Hiring For Genpact-Data Scientist- Forecasting...    4.0    3d ago
# 2  Genpact - Data Scientist - Forecasting/Python/...    4.0    5d ago
# 3                                     Data Scientist    4.3   20d ago
# 4                                     Data Scientist    4.0   13d ago
# 5                                     Data Scientist    4.1   17d ago
# 6                 Associate Manager - Data Scientist    4.1   18d ago
# 7                                     Data Scientist    4.3   30d ago
# 8                                     Data Scientist    4.2   19d ago
# 9                   Data Scientist - Noida/Bangalore    3.9   19d ago

# %% [markdown]
# # Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))



url= "https://www.ambitionbox.com/"
driver.get(url)
time.sleep(10)

salaries = driver.find_element(By.XPATH,'//ul[@class="nav-list-wrapper"]/li[3]/a')
salaries.click()

sub_salaries = driver.find_element(By.XPATH, '//a[@title="Browse salaries"]')
sub_salaries.click()

job_profile = driver.find_element(By.XPATH,'//input[@id="jobProfileSearchbox"]')
job_profile.send_keys("Data Scientist")

suggestion = driver.find_element(By.XPATH, '//*[@id="salaries"]/main/section[1]/div[2]/div[1]/span/div/div/div[1]')
suggestion.click()



time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19200/2951310422.py in <module>
#      16 job_profile.send_keys("Data Scientist")
#      17
# ---> 18 suggestion = driver.find_element(By.XPATH, '//*[@id="salaries"]/main/section[1]/div[2]/div[1]/span/div/div/div[1]')
#      19 suggestion.click()
#      20
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     853             value = '[name="%s"]' % value
#     854
# --> 855         return self.execute(Command.FIND_ELEMENT, {
#     856             'using': by,
#     857             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     426         response = self.command_executor.execute(driver_command, params)
#     427         if response:
# ...

# %%
# I tried many ways to findout the error shown- but i couldnot make possible
